# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
#importing the csv file
data = pd.read_csv("D:/Masters/SEM 2/Data Visualization/Assignment 3/data.csv")

# %%
data.head()
# Out:
#          game_name    month  total_ticket_sales total_ticket_sales_count  \
# 0            Lotto  January            680904.0                  169,005
# 1  Lucky Day Lotto  January            519490.0                  406,786
# 2   Mega Millions   January            623048.0                  149,777
# 3           Pick 3  January            117236.0                    7,565
# 4   Pick3 Fireball  January             59059.0                    3,801
#
#    year zip_code
# 0  2017   Online
# 1  2017   Online
# 2  2017   Online
# 3  2017   Online
# 4  2017   Online

# %%
#to find the lowest zip code
data.zip_code.min()
# Out:
# '60002'

# %%
#to find all entries with a sales amount lower than 60000
sales = data[data.total_ticket_sales < 60000]

# %%
sales.head()
# Out:
#           game_name    month  total_ticket_sales total_ticket_sales_count  \
# 4    Pick3 Fireball  January             59059.0                    3,801
# 8          EZ Match  January              3344.0                    3,344
# 10            Lotto  January             22696.0                    6,883
# 11  Lucky Day Lotto  January             27941.0                   11,913
# 12   Mega Millions   January             21131.0                    7,693
#
#     year zip_code
# 4   2017   Online
# 8   2017    60002
# 10  2017    60002
# 11  2017    60002
# 12  2017    60002

# %%
data.head(20)
# Out:
#           game_name    month  total_ticket_sales total_ticket_sales_count  \
# 0             Lotto  January            680904.0                  169,005
# 1   Lucky Day Lotto  January            519490.0                  406,786
# 2    Mega Millions   January            623048.0                  149,777
# 3            Pick 3  January            117236.0                    7,565
# 4    Pick3 Fireball  January             59059.0                    3,801
# 5            Pick 4  January            145418.0                    9,807
# 6    Pick4 Fireball  January             80696.0                    5,441
# 7         Powerball  January            680088.0                  108,469
# 8          EZ Match  January              3344.0                    3,344
# 9    Instant Rollup  January            364200.0              Not Tracked
# 10            Lotto  January             22696.0                    6,883
# 11  Lucky Day Lotto  January             27941.0                   11,913
# ...

# %%
from adjustText import adjust_text
from sklearn.preprocessing import normalize
x = data.zip_code.head(20)
y = data.total_ticket_sales.head(20)
annotations= data.total_ticket_sales.head(20)
plt.figure(figsize=(10,10))
plt.scatter(x, y, c='green', marker='^')
texts = [plt.text(x[i], y[i], annotations[i]) for i in range(20)]

# %%
#I have used the scatter plot as the visualization for this particular data because the markers in the scatter plot show individual data points
# and as we were required to to show the sales amounts and their corresponding zip codes this visualization feels perfect for this situation
# As we see, among the first 20 rows of data, the data is grouped into 3 zip codes (online, 60002 and 60004). Scatter plot helps in keeping the individuality by showing each data point
# and not summing up the values of the sales in a particular zip code

# %%
# %notebook "D:/Masters/SEM 2/Data Visualization/Assignment 3/SaiAnurag-Kasula-ProgrammingAssignment3.ipynb"

# %%
# %notebook "D:/Masters/SEM 2/Data Visualization/Assignment 3/SaiAnurag-Kasula-ProgrammingAssignment3.ipynb"
